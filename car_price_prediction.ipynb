# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
car_data = pd.read_csv("car_price.csv")

# %%
car_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 200       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [5 rows x 26 columns]

# %%
car_data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
car_data.shape
# Out:
# (205, 26)

# %%
car_data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
car_data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car_data.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
for i in car_data[['symboling','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype','cylindernumber','fuelsystem']]:
    sns.countplot(car_data[i], data= car_data,palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
plt.figure(figsize=(15,6))
sns.distplot(car_data['price'])
plt.xticks(rotation =90)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
p = PowerTransformer(method = 'box-cox')
car_data['price'] = p.fit_transform(car_data[['price']])
sns.distplot(car_data.price)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
car_data.drop(columns = ['car_ID'],inplace = True)

# %%
car = car_data.CarName.str.split(expand = True)
Brand = car[0]
car_data['Brand'] = Brand
car_data
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0    convertible        rwd          front       88.6      168.8  ...
# 1    convertible        rwd          front       88.6      168.8  ...
# 2      hatchback        rwd          front       94.5      171.2  ...
# 3          sedan        fwd          front       99.8      176.6  ...
# 4          sedan        4wd          front       99.4      176.6  ...
# ..           ...        ...            ...        ...        ...  ...
# 200        sedan        rwd          front      109.1      188.8  ...
# 201        sedan        rwd          front      109.1      188.8  ...
# 202        sedan        rwd          front      109.1      188.8  ...
# 203        sedan        rwd          front      109.1      188.8  ...
# 204        sedan        rwd          front      109.1      188.8  ...
#
#      fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 0          mpfi       3.47    2.68              9.0        111     5000
# 1          mpfi       3.47    2.68              9.0        111     5000
# 2          mpfi       2.68    3.47              9.0        154     5000
# 3          mpfi       3.19    3.40             10.0        102     5500
# 4          mpfi       3.19    3.40              8.0        115     5500
# ..          ...        ...     ...              ...        ...      ...
# 200        mpfi       3.78    3.15              9.5        114     5400
# 201        mpfi       3.78    3.15              8.7        160     5300
# 202        mpfi       3.58    2.87              8.8        134     5500
# 203         idi       3.01    3.40             23.0        106     4800
# 204        mpfi       3.78    3.15              9.5        114     5400
#
#     citympg  highwaympg     price        Brand
# 0        21          27  0.468026  alfa-romero
# 1        21          27  0.826801  alfa-romero
# 2        19          26  0.826801  alfa-romero
# 3        24          30  0.530367         audi
# 4        18          22  0.918898         audi
# ..      ...         ...       ...          ...
# 200      23          28  0.861224        volvo
# 201      19          25  1.056467        volvo
# 202      18          23  1.234104        volvo
# 203      26          27  1.296801        volvo
# 204      19          25  1.306261        volvo
#
# [205 rows x 26 columns]

# %%
car
# Out:
#                0             1     2     3     4
# 0    alfa-romero        giulia  None  None  None
# 1    alfa-romero       stelvio  None  None  None
# 2    alfa-romero  Quadrifoglio  None  None  None
# 3           audi           100    ls  None  None
# 4           audi         100ls  None  None  None
# ..           ...           ...   ...   ...   ...
# 200        volvo          145e  (sw)  None  None
# 201        volvo         144ea  None  None  None
# 202        volvo         244dl  None  None  None
# 203        volvo           246  None  None  None
# 204        volvo         264gl  None  None  None
#
# [205 rows x 5 columns]

# %%
car_data.drop(columns = ['CarName'],inplace = True)

# %%
car_data.head(10)
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
# 5          2      gas        std        two        sedan        fwd
# 6          1      gas        std       four        sedan        fwd
# 7          1      gas        std       four        wagon        fwd
# 8          1      gas      turbo       four        sedan        fwd
# 9          0      gas      turbo        two    hatchback        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  fuelsystem  boreratio  \
# 0          front       88.6      168.8      64.1  ...        mpfi       3.47
# 1          front       88.6      168.8      64.1  ...        mpfi       3.47
# 2          front       94.5      171.2      65.5  ...        mpfi       2.68
# 3          front       99.8      176.6      66.2  ...        mpfi       3.19
# 4          front       99.4      176.6      66.4  ...        mpfi       3.19
# 5          front       99.8      177.3      66.3  ...        mpfi       3.19
# 6          front      105.8      192.7      71.4  ...        mpfi       3.19
# 7          front      105.8      192.7      71.4  ...        mpfi       3.19
# 8          front      105.8      192.7      71.4  ...        mpfi       3.13
# 9          front       99.5      178.2      67.9  ...        mpfi       3.13
#
#   stroke compressionratio  horsepower peakrpm  citympg  highwaympg     price  \
# 0   2.68              9.0         111    5000       21          27  0.468026
# 1   2.68              9.0         111    5000       21          27  0.826801
# 2   3.47              9.0         154    5000       19          26  0.826801
# 3   3.40             10.0         102    5500       24          30  0.530367
# 4   3.40              8.0         115    5500       18          22  0.918898
# 5   3.40              8.5         110    5500       19          25  0.691582
# 6   3.40              8.5         110    5500       19          25  0.942694
# 7   3.40              8.5         110    5500       19          25  1.046370
# 8   3.40              8.3         140    5500       17          20  1.378871
# 9   3.40              7.0         160    5500       16          22  0.956091
#
#          Brand
# 0  alfa-romero
# 1  alfa-romero
# 2  alfa-romero
# 3         audi
# 4         audi
# 5         audi
# 6         audi
# 7         audi
# 8         audi
# 9         audi
#
# [10 rows x 25 columns]

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   fueltype          205 non-null    object
#  2   aspiration        205 non-null    object
#  3   doornumber        205 non-null    object
#  4   carbody           205 non-null    object
#  5   drivewheel        205 non-null    object
#  6   enginelocation    205 non-null    object
#  7   wheelbase         205 non-null    float64
#  8   carlength         205 non-null    float64
#  9   carwidth          205 non-null    float64
#  10  carheight         205 non-null    float64
#  11  curbweight        205 non-null    int64
#  12  enginetype        205 non-null    object
#  13  cylindernumber    205 non-null    object
#  14  enginesize        205 non-null    int64
#  15  fuelsystem        205 non-null    object
#  16  boreratio         205 non-null    float64
#  17  stroke            205 non-null    float64
#  18  compressionratio  205 non-null    float64
#  19  horsepower        205 non-null    int64
#  20  peakrpm           205 non-null    int64
#  21  citympg           205 non-null    int64
#  22  highwaympg        205 non-null    int64
#  23  price             205 non-null    float64
#  24  Brand             205 non-null    object
# dtypes: float64(8), int64(7), object(10)
# memory usage: 40.2+ KB

# %%
car_data.nunique()
# Out:
# symboling             6
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# Brand                28
# dtype: int64

# %%
car_data.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# citympg           -0.035823  -0.470414  -0.670909 -0.642704  -0.048640
# highwaympg         0.034606  -0.544082  -0.704662 -0.677218  -0.107358
# price             -0.091310   0.633710   0.791501  0.795125   0.181206
#
#                   curbweight  enginesize  boreratio    stroke  \
# symboling          -0.227691   -0.105790  -0.130051 -0.008735
# wheelbase           0.776386    0.569329   0.488750  0.160959
# carlength           0.877728    0.683360   0.606454  0.129533
# carwidth            0.867032    0.735433   0.559150  0.182942
# carheight           0.295572    0.067149   0.171071 -0.055307
# curbweight          1.000000    0.850594   0.648480  0.168790
# enginesize          0.850594    1.000000   0.583774  0.203129
# boreratio           0.648480    0.583774   1.000000 -0.055909
# stroke              0.168790    0.203129  -0.055909  1.000000
# compressionratio    0.151362    0.028971   0.005197  0.186110
# horsepower          0.750739    0.809769   0.573677  0.080940
# peakrpm            -0.266243   -0.244660  -0.254976 -0.067964
# citympg            -0.757414   -0.653658  -0.584532 -0.042145
# highwaympg         -0.797465   -0.677470  -0.587012 -0.043931
# price               0.888370    0.779846   0.623688  0.112503
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# symboling                -0.178515    0.070873  0.273606 -0.035823
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.087969    0.803146 -0.088311 -0.795560
#
#                   highwaympg     price
# symboling           0.034606 -0.091310
# wheelbase          -0.544082  0.633710
# carlength          -0.704662  0.791501
# carwidth           -0.677218  0.795125
# carheight          -0.107358  0.181206
# curbweight         -0.797465  0.888370
# enginesize         -0.677470  0.779846
# boreratio          -0.587012  0.623688
# stroke             -0.043931  0.112503
# compressionratio    0.265201  0.087969
# horsepower         -0.770544  0.803146
# peakrpm            -0.054275 -0.088311
# citympg             0.971337 -0.795560
# highwaympg          1.000000 -0.793187
# price              -0.793187  1.000000

# %%
car_data.corr().style.background_gradient(cmap='binary')
# Out:
# <style  type="text/css" >
# #T_fde37_row0_col0,#T_fde37_row1_col1,#T_fde37_row2_col2,#T_fde37_row3_col3,#T_fde37_row4_col4,#T_fde37_row5_col5,#T_fde37_row6_col6,#T_fde37_row7_col7,#T_fde37_row8_col8,#T_fde37_row9_col9,#T_fde37_row10_col10,#T_fde37_row11_col11,#T_fde37_row12_col12,#T_fde37_row13_col13,#T_fde37_row14_col14{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_fde37_row0_col1,#T_fde37_row7_col8{
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }#T_fde37_row0_col2,#T_fde37_row5_col0{
#             background-color:  #cbcbcb;
#             color:  #000000;
#         }#T_fde37_row0_col3{
#             background-color:  #bcbcbc;
#             color:  #000000;
#         }#T_fde37_row0_col4,#T_fde37_row4_col0,#T_fde37_row5_col13,#T_fde37_row9_col11,#T_fde37_row10_col12,#T_fde37_row11_col8,#T_fde37_row11_col9,#T_fde37_row12_col7,#T_fde37_row12_col10,#T_fde37_row12_col14,#T_fde37_row13_col1,#T_fde37_row13_col2,#T_fde37_row13_col3,#T_fde37_row13_col5,#T_fde37_row13_col6,#T_fde37_row13_col7,#T_fde37_row13_col14,#T_fde37_row14_col12,#T_fde37_row14_col13{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_fde37_row0_col5,#T_fde37_row12_col4{
#             background-color:  #aeaeae;
#             color:  #000000;
#         }#T_fde37_row0_col6{
#             background-color:  #a8a8a8;
#             color:  #000000;
#         }#T_fde37_row0_col7{
#             background-color:  #b6b6b6;
#             color:  #000000;
#         }#T_fde37_row0_col8{
#             background-color:  #f1f1f1;
#             color:  #000000;
#         }#T_fde37_row0_col9{
#             background-color:  #d2d2d2;
#             color:  #000000;
#         }#T_fde37_row0_col10{
#             background-color:  #848484;
#             color:  #000000;
#         }#T_fde37_row0_col11{
#             background-color:  #818181;
#             color:  #000000;
#         }#T_fde37_row0_col12{
#             background-color:  #939393;
#             color:  #000000;
#         }#T_fde37_row0_col13,#T_fde37_row7_col4{
#             background-color:  #898989;
#             color:  #000000;
#         }#T_fde37_row0_col14,#T_fde37_row11_col14{
#             background-color:  #9b9b9b;
#             color:  #000000;
#         }#T_fde37_row1_col0{
#             background-color:  #fefefe;
#             color:  #000000;
#         }#T_fde37_row1_col2,#T_fde37_row3_col5,#T_fde37_row5_col2{
#             background-color:  #121212;
#             color:  #f1f1f1;
#         }#T_fde37_row1_col3,#T_fde37_row1_col5,#T_fde37_row6_col14,#T_fde37_row14_col2,#T_fde37_row14_col3{
#             background-color:  #1f1f1f;
#             color:  #f1f1f1;
#         }#T_fde37_row1_col4,#T_fde37_row4_col1,#T_fde37_row10_col7{
#             background-color:  #444444;
#             color:  #f1f1f1;
#         }#T_fde37_row1_col6{
#             background-color:  #414141;
#             color:  #f1f1f1;
#         }#T_fde37_row1_col7{
#             background-color:  #525252;
#             color:  #f1f1f1;
#         }#T_fde37_row1_col8{
#             background-color:  #c9c9c9;
#             color:  #000000;
#         }#T_fde37_row1_col9,#T_fde37_row4_col7{
#             background-color:  #858585;
#             color:  #000000;
#         }#T_fde37_row1_col10{
#             background-color:  #5b5b5b;
#             color:  #f1f1f1;
#         }#T_fde37_row1_col11,#T_fde37_row2_col13{
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }#T_fde37_row1_col12,#T_fde37_row2_col8{
#             background-color:  #d0d0d0;
#             color:  #000000;
#         }#T_fde37_row1_col13,#T_fde37_row11_col4{
#             background-color:  #dbdbdb;
#             color:  #000000;
#         }#T_fde37_row1_col14{
#             background-color:  #343434;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col0,#T_fde37_row5_col11,#T_fde37_row7_col12,#T_fde37_row11_col1{
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }#T_fde37_row2_col1,#T_fde37_row5_col3{
#             background-color:  #141414;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col3{
#             background-color:  #181818;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col4,#T_fde37_row7_col1{
#             background-color:  #545454;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col5{
#             background-color:  #111111;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col6{
#             background-color:  #303030;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col7,#T_fde37_row2_col10,#T_fde37_row7_col6{
#             background-color:  #3f3f3f;
#             color:  #f1f1f1;
#         }#T_fde37_row2_col9,#T_fde37_row11_col13{
#             background-color:  #969696;
#             color:  #000000;
#         }#T_fde37_row2_col11{
#             background-color:  #e5e5e5;
#             color:  #000000;
#         }#T_fde37_row2_col12{
#             background-color:  #ededed;
#             color:  #000000;
#         }#T_fde37_row2_col14,#T_fde37_row3_col14,#T_fde37_row10_col6{
#             background-color:  #1d1d1d;
#             color:  #f1f1f1;
#         }#T_fde37_row3_col0{
#             background-color:  #cccccc;
#             color:  #000000;
#         }#T_fde37_row3_col1,#T_fde37_row14_col6{
#             background-color:  #212121;
#             color:  #f1f1f1;
#         }#T_fde37_row3_col2{
#             background-color:  #171717;
#             color:  #f1f1f1;
#         }#T_fde37_row3_col4{
#             background-color:  #777777;
#             color:  #000000;
#         }#T_fde37_row3_col6,#T_fde37_row6_col3{
#             background-color:  #282828;
#             color:  #f1f1f1;
#         }#T_fde37_row3_col7,#T_fde37_row6_col1{
#             background-color:  #474747;
#             color:  #f1f1f1;
#         }#T_fde37_row3_col8,#T_fde37_row9_col0,#T_fde37_row9_col8{
#             background-color:  #c3c3c3;
#             color:  #000000;
#         }#T_fde37_row3_col9{
#             background-color:  #929292;
#             color:  #000000;
#         }#T_fde37_row3_col10{
#             background-color:  #333333;
#             color:  #f1f1f1;
#         }#T_fde37_row3_col11{
#             background-color:  #d9d9d9;
#             color:  #000000;
#         }#T_fde37_row3_col12{
#             background-color:  #e9e9e9;
#             color:  #000000;
#         }#T_fde37_row3_col13,#T_fde37_row6_col13{
#             background-color:  #eeeeee;
#             color:  #000000;
#         }#T_fde37_row4_col2{
#             background-color:  #4c4c4c;
#             color:  #f1f1f1;
#         }#T_fde37_row4_col3{
#             background-color:  #6e6e6e;
#             color:  #000000;
#         }#T_fde37_row4_col5{
#             background-color:  #646464;
#             color:  #f1f1f1;
#         }#T_fde37_row4_col6{
#             background-color:  #8e8e8e;
#             color:  #000000;
#         }#T_fde37_row4_col8,#T_fde37_row10_col13,#T_fde37_row12_col6{
#             background-color:  #fcfcfc;
#             color:  #000000;
#         }#T_fde37_row4_col9,#T_fde37_row13_col9{
#             background-color:  #838383;
#             color:  #000000;
#         }#T_fde37_row4_col10,#T_fde37_row4_col13{
#             background-color:  #9d9d9d;
#             color:  #000000;
#         }#T_fde37_row4_col11{
#             background-color:  #ebebeb;
#             color:  #000000;
#         }#T_fde37_row4_col12{
#             background-color:  #959595;
#             color:  #000000;
#         }#T_fde37_row4_col14{
#             background-color:  #747474;
#             color:  #000000;
#         }#T_fde37_row5_col1{
#             background-color:  #252525;
#             color:  #f1f1f1;
#         }#T_fde37_row5_col4{
#             background-color:  #757575;
#             color:  #000000;
#         }#T_fde37_row5_col6{
#             background-color:  #161616;
#             color:  #f1f1f1;
#         }#T_fde37_row5_col7{
#             background-color:  #383838;
#             color:  #f1f1f1;
#         }#T_fde37_row5_col8{
#             background-color:  #c7c7c7;
#             color:  #000000;
#         }#T_fde37_row5_col9{
#             background-color:  #979797;
#             color:  #000000;
#         }#T_fde37_row5_col10

# %%
plt.figure(figsize=(10,10))
sns.heatmap(car_data.corr())
plt.show()

# %%
car_data.nunique()
# Out:
# symboling             6
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# Brand                28
# dtype: int64

# %%
car_data = car_data[car_data[("cylindernumber")].map(car_data["cylindernumber"].value_counts())>3]
car_data = car_data[car_data[("enginetype")].map(car_data["enginetype"].value_counts())>6]
car_data = car_data[car_data[("fueltype")].map(car_data["fueltype"].value_counts())>3]
car_data = car_data[car_data[("Brand")].map(car_data["Brand"].value_counts())>9]
car_data = car_data[car_data.carbody!='convertable']
car_data = car_data[car_data.fueltype!='mfi']

# %%
car_data.shape
# Out:
# (119, 25)

# %%
car_data.head(10)
# Out:
#     symboling fueltype aspiration doornumber    carbody drivewheel  \
# 30          2      gas        std        two  hatchback        fwd
# 31          2      gas        std        two  hatchback        fwd
# 32          1      gas        std        two  hatchback        fwd
# 33          1      gas        std        two  hatchback        fwd
# 34          1      gas        std        two  hatchback        fwd
# 35          0      gas        std       four      sedan        fwd
# 36          0      gas        std       four      wagon        fwd
# 37          0      gas        std        two  hatchback        fwd
# 38          0      gas        std        two  hatchback        fwd
# 39          0      gas        std       four      sedan        fwd
#
#    enginelocation  wheelbase  carlength  carwidth  ...  fuelsystem  boreratio  \
# 30          front       86.6      144.6      63.9  ...        1bbl       2.91
# 31          front       86.6      144.6      63.9  ...        1bbl       2.91
# 32          front       93.7      150.0      64.0  ...        1bbl       2.91
# 33          front       93.7      150.0      64.0  ...        1bbl       2.91
# 34          front       93.7      150.0      64.0  ...        1bbl       2.91
# 35          front       96.5      163.4      64.0  ...        1bbl       2.91
# 36          front       96.5      157.1      63.9  ...        1bbl       2.92
# 37          front       96.5      167.5      65.2  ...        1bbl       3.15
# 38          front       96.5      167.5      65.2  ...        1bbl       3.15
# 39          front       96.5      175.4      65.2  ...        1bbl       3.15
#
#    stroke compressionratio  horsepower peakrpm  citympg  highwaympg     price  \
# 30   3.41              9.6          58    4800       49          54 -1.302606
# 31   3.41              9.2          76    6000       31          38 -1.135683
# 32   3.07             10.1          60    5500       38          42 -1.884488
# 33   3.41              9.2          76    6000       30          34 -1.279509
# 34   3.41              9.2          76    6000       30          34 -1.023145
# 35   3.41              9.2          76    6000       30          34 -0.958331
# 36   3.41              9.2          76    6000       30          34 -0.958331
# 37   3.58              9.0          86    5800       27          33 -0.742768
# 38   3.58              9.0          86    5800       27          33 -0.382617
# 39   3.58              9.0          86    5800       27          33 -0.451053
#
#     Brand
# 30  honda
# 31  honda
# 32  honda
# 33  honda
# 34  honda
# 35  honda
# 36  honda
# 37  honda
# 38  honda
# 39  honda
#
# [10 rows x 25 columns]

# %%
x=car_data.iloc[:,0:23]
y=car_data[['price']]

# %%
x = car_data.drop(columns = ['price'])

# %%
x.shape
# Out:
# (119, 24)

# %%
y.shape
# Out:
# (119, 1)

# %%
nomi_col = [4,5,12,15,23,13]
ordinal_col = [1,2,3,6]
numeric_col = [0,9,10,14,16,17,18,20,21,22]
KBin_col = [11,19]
Bina_col = [7,8]

# %%
from sklearn.preprocessing import KBinsDiscretizer,Binarizer,PowerTransformer
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.compose import make_column_transformer
from sklearn import set_config
trans = make_column_transformer((OneHotEncoder(sparse = False),nomi_col),
(OrdinalEncoder(),ordinal_col),
(PowerTransformer(),numeric_col),
(KBinsDiscretizer(),KBin_col),
(Binarizer(threshold = 50),Bina_col),
remainder = 'passthrough')
set_config(display ='diagram')
trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder', OneHotEncoder(sparse=False),
#                                  [4, 5, 12, 15, 23, 13]),
#                                 ('ordinalencoder', OrdinalEncoder(),
#                                  [1, 2, 3, 6]),
#                                 ('powertransformer', PowerTransformer(),
#                                  [0, 9, 10, 14, 16, 17, 18, 20, 21, 22]),
#                                 ('kbinsdiscretizer', KBinsDiscretizer(),
#                                  [11, 19]),
#                                 ('binarizer', Binarizer(threshold=50), [7, 8])])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
from sklearn.pipeline import make_pipeline
pipe = make_pipeline(trans,model)

# %%
model
# Out:
# LinearRegression()

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   [4, 5, 12, 15, 23, 13]),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(),
#                                                   [1, 2, 3, 6]),
#                                                  ('powertransformer',
#                                                   PowerTransformer(),
#                                                   [0, 9, 10, 14, 16, 17, 18, 20,
#                                                    21, 22]),
#                                                  ('kbinsdiscretizer',
#                                                   KBinsDiscretizer(),
#                                                   [11, 19]),
#                                                  ('binarizer',
#                                                   Binarizer(threshold=50),
#                                                   [7, 8])])),
#                 ('linearregression', LinearRegression())])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   [4, 5, 12, 15, 23, 13]),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(),
#                                                   [1, 2, 3, 6]),
#                                                  ('powertransformer',
#                                                   PowerTransformer(),
#                                                   [0, 9, 10, 14, 16, 17, 18, 20,
#                                                    21, 22]),
#                                                  ('kbinsdiscretizer',
#                                                   KBinsDiscretizer(),
#                                                   [11, 19]),
#                                                  ('binarizer',
#                                                   Binarizer(threshold=50),
#                                                   [7, 8])])),
#                 ('linearregression', LinearRegression())])

# %%
pred = pipe.predict(x_test)

# %%
print("Training Accuracy :", pipe.score(x_train, y_train))
print("Testing Accuracy :", pipe.score(x_test, y_test))
# Out:
# Training Accuracy : 0.9641945496446288
# Testing Accuracy : 0.660119941640305

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(pred,y_test)
# Out:
# 0.14020637044241568

# %%
model.coef_
# Out:
# array([[ 8.78469964e+12,  8.78469964e+12,  8.78469964e+12,
#          8.78469964e+12,  8.78469964e+12,  2.65625000e-01,
#         -2.52929688e-01, -7.71484375e-02,  1.51367188e-01,
#         -1.97875977e-01,  4.58984375e-02, -8.02001953e-02,
#          8.72192383e-02, -6.28173828e-01, -2.48046875e-01,
#          1.34094238e-01,  3.56933594e-01,  3.64868164e-01,
#          3.34472656e-01,  2.94189453e-01, -4.14794922e-01,
#         -1.17187500e-01, -2.05932617e-01, -7.42187500e-02,
#         -4.58984375e-02,  2.28027344e-01,  2.55065918e-01,
#         -2.53662109e-01, -1.28051758e-01,  2.25219727e-01,
#         -1.02539062e-01,  6.10351562e-05,  4.00390625e-02,
#          2.87353516e-01, -1.05346680e-01,  3.25195312e-01,
#         -2.25830078e-01, -4.39453125e-02, -1.41601562e-02,
#          0.00000000e+00, -1.83593750e-01,  5.51757812e-02,
#         -1.58935547e-01, -3.78417969e-03, -2.70996094e-01,
#          1.50878906e-01,  2.81250000e-01, -9.53369141e-02,
#          2.16552734e-01,  2.17773438e-01, -1.77368164e-01,
#         -1.45019531e-01,  0.00000000e+00,  0.00000000e+00]])
